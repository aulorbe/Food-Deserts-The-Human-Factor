# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_excel('DataDownload2015.xlsx', sheet_name='Food Access Research Atlas')
df.head()
# Out:
#    CensusTract    State   County  Urban  POP2010  OHU2010  GroupQuartersFlag  \
# 0   1001020100  Alabama  Autauga      1     1912      693                  0
# 1   1001020200  Alabama  Autauga      1     2170      743                  0
# 2   1001020300  Alabama  Autauga      1     3373     1256                  0
# 3   1001020400  Alabama  Autauga      1     4386     1722                  0
# 4   1001020500  Alabama  Autauga      1    10766     4082                  0
#
#    NUMGQTRS  PCTGQTRS  LILATracts_1And10    ...      TractSeniors  TractWhite  \
# 0         0  0.000000                  0    ...               221        1622
# 1       181  0.083410                  0    ...               214         888
# 2         0  0.000000                  0    ...               439        2576
# 3         0  0.000000                  0    ...               904        4086
# 4       181  0.016812                  0    ...              1126        8666
#
#    TractBlack  TractAsian  TractNHOPI  TractAIAN  TractOMultir  TractHispanic  \
# 0         217          14           0         14            45             44
# 1        1217           5           0          5            55             75
# 2         647          17           5         11           117             87
# 3         193          18           4         11            74             85
# 4        1437         296           9         48           310            355
#
#    TractHUNV  TractSNAP
# 0         26        112
# 1         87        202
# 2        108        120
# 3         19         82
# 4        198        488
#
# [5 rows x 147 columns]

# %%
df.set_index('CensusTract', inplace=True)
target_df = df[['LILATracts_halfAnd10']]
target_df.head()
# Out:
#              LILATracts_halfAnd10
# CensusTract
# 1001020100                      0
# 1001020200                      0
# 1001020300                      0
# 1001020400                      0
# 1001020500                      0

# %%
df = df[['OHU2010', 'PovertyRate', 'MedianFamilyIncome', 'TractKids','TractSeniors','TractWhite','TractBlack','TractAsian', 
         'TractNHOPI','TractAIAN','TractOMultir','TractHispanic','TractHUNV','TractSNAP']]
df = df.join(target_df)
df.head()
# Out:
#              OHU2010  PovertyRate  MedianFamilyIncome  TractKids  \
# CensusTract
# 1001020100       693         10.0               74750        507
# 1001020200       743         18.2               51875        606
# 1001020300      1256         19.1               52905        894
# 1001020400      1722          3.3               68079       1015
# 1001020500      4082          8.5               77819       3162
#
#              TractSeniors  TractWhite  TractBlack  TractAsian  TractNHOPI  \
# CensusTract
# 1001020100            221        1622         217          14           0
# 1001020200            214         888        1217           5           0
# 1001020300            439        2576         647          17           5
# 1001020400            904        4086         193          18           4
# 1001020500           1126        8666        1437         296           9
#
#              TractAIAN  TractOMultir  TractHispanic  TractHUNV  TractSNAP  \
# CensusTract
# 1001020100          14            45             44         26        112
# 1001020200           5            55             75         87        202
# 1001020300          11           117             87        108        120
# 1001020400          11            74             85         19         82
# 1001020500          48           310            355        198        488
#
#              LILATracts_halfAnd10
# CensusTract
# 1001020100                      0
# 1001020200                      0
# 1001020300                      0
# 1001020400                      0
# 1001020500                      0

# %% [markdown]
# ##### target label info:
# LILATracts_halfAnd10 = Low-income census tracts where a significant number (at least 500 people) or share (at least 33 percent) of the population is greater than ½ mile from the nearest supermarket, supercenter, or large grocery store for an urban area or greater than 10 miles for a rural area. Using this measure, an estimated 54.4 million people, or 17.7 percent of the U.S. population, live in tracts that are low-income and low access and are more than ½ mile or 10 miles from the nearest supermarket.

# %%
health_stats = pd.read_csv('500_Cities__Census_Tract-level_Data__GIS_Friendly_Format___2018_release.csv')
health_stats.head()
# Out:
#   StateAbbr   PlaceName  PlaceFIPS   TractFIPS        Place_TractID  \
# 0        AL  Birmingham     107000  1073000100  0107000-01073000100
# 1        AL  Birmingham     107000  1073000300  0107000-01073000300
# 2        AL  Birmingham     107000  1073000400  0107000-01073000400
# 3        AL  Birmingham     107000  1073000500  0107000-01073000500
# 4        AL  Birmingham     107000  1073000700  0107000-01073000700
#
#    Population2010  ACCESS2_CrudePrev ACCESS2_Crude95CI  ARTHRITIS_CrudePrev  \
# 0            3042               23.3      (20.6, 26.3)                 31.3
# 1            2735               28.5      (25.2, 31.7)                 30.2
# 2            3338               23.9      (20.5, 27.6)                 31.7
# 3            2864               25.8      (22.0, 29.9)                 35.6
# 4            2577               29.4      (24.8, 34.2)                 37.2
#
#   ARTHRITIS_Crude95CI                ...                 PAPTEST_Crude95CI  \
# 0        (30.3, 32.5)                ...                      (83.4, 86.6)
# 1        (29.0, 31.4)                ...                      (81.9, 85.6)
# 2        (30.3, 33.0)                ...                      (82.3, 86.8)
# 3        (34.1, 37.0)                ...                      (82.1, 86.5)
# 4        (35.8, 38.6)                ...                      (82.2, 87.1)
#
#   PHLTH_CrudePrev  PHLTH_Crude95CI SLEEP_CrudePrev  SLEEP_Crude95CI  \
# 0            20.0     (18.5, 21.7)            45.5     (44.3, 46.5)
# 1            20.6     (18.8, 22.5)            44.5     (43.2, 45.7)
# 2            19.3     (17.6, 21.4)            45.7     (44.2, 47.0)
# 3            21.8     (19.8, 24.0)            46.1     (44.5, 47.4)
# 4            25.1     (22.9, 27.6)            48.3     (46.6, 49.7)
#
#   STROKE_CrudePrev  STROKE_Crude95CI TEETHLOST_CrudePrev  TEETHLOST_Crude95CI  \
# 0              5.6      ( 5.1,  6.1)                28.9         (23.7, 35.1)
# 1              5.9      ( 5.3,  6.5)                32.9         (25.5, 40.2)
# 2              5.7      ( 5.1,  6.4)                28.6         (22.0, 35.1)
# 3              7.7      ( 6.9,  8.6)                34.0         (24.4, 42.9)
# 4              9.5      ( 8.4, 10.6)                43.2         (33.2, 53.2)
#
#                         Geolocation
# 0  (33.57943283260, -86.7228323926)
# 1  (33.54282086860, -86.7524339780)
# 2  (33.56324496330, -86.7640474064)
# 3  (33.54424045940, -86.7749130719)
# 4  (33.55254061390, -86.8016893706)
#
# [5 rows x 63 columns]

# %%
health_stats.set_index('TractFIPS', inplace=True)
health_stats.head()
# Out:
#            StateAbbr   PlaceName  PlaceFIPS        Place_TractID  \
# TractFIPS
# 1073000100        AL  Birmingham     107000  0107000-01073000100
# 1073000300        AL  Birmingham     107000  0107000-01073000300
# 1073000400        AL  Birmingham     107000  0107000-01073000400
# 1073000500        AL  Birmingham     107000  0107000-01073000500
# 1073000700        AL  Birmingham     107000  0107000-01073000700
#
#             Population2010  ACCESS2_CrudePrev ACCESS2_Crude95CI  \
# TractFIPS
# 1073000100            3042               23.3      (20.6, 26.3)
# 1073000300            2735               28.5      (25.2, 31.7)
# 1073000400            3338               23.9      (20.5, 27.6)
# 1073000500            2864               25.8      (22.0, 29.9)
# 1073000700            2577               29.4      (24.8, 34.2)
#
#             ARTHRITIS_CrudePrev ARTHRITIS_Crude95CI  BINGE_CrudePrev  \
# TractFIPS
# 1073000100                 31.3        (30.3, 32.5)             11.5
# 1073000300                 30.2        (29.0, 31.4)             12.0
# 1073000400                 31.7        (30.3, 33.0)             11.6
# 1073000500                 35.6        (34.1, 37.0)             10.0
# 1073000700                 37.2        (35.8, 38.6)              8.4
#
#                           ...                PAPTEST_Crude95CI  \
# TractFIPS                 ...
# 1073000100                ...                     (83.4, 86.6)
# 1073000300                ...                     (81.9, 85.6)
# 1073000400                ...                     (82.3, 86.8)
# 1073000500                ...                     (82.1, 86.5)
# 1073000700                ...                     (82.2, 87.1)
#
#             PHLTH_CrudePrev PHLTH_Crude95CI  SLEEP_CrudePrev SLEEP_Crude95CI  \
# TractFIPS
# 1073000100             20.0    (18.5, 21.7)             45.5    (44.3, 46.5)
# 1073000300             20.6    (18.8, 22.5)             44.5    (43.2, 45.7)
# 1073000400             19.3    (17.6, 21.4)             45.7    (44.2, 47.0)
# 1073000500             21.8    (19.8, 24.0)             46.1    (44.5, 47.4)
# 1073000700             25.1    (22.9, 27.6)             48.3    (46.6, 49.7)
#
#             STROKE_CrudePrev STROKE_Crude95CI  TEETHLOST_CrudePrev  \
# TractFIPS
# 1073000100               5.6     ( 5.1,  6.1)                 28.9
# 1073000300               5.9     ( 5.3,  6.5)                 32.9
# 1073000400               5.7     ( 5.1,  6.4)                 28.6
# 1073000500               7.7     ( 6.9,  8.6)                 34.0
# 1073000700               9.5     ( 8.4, 10.6)                 43.2
#
#            TEETHLOST_Crude95CI                       Geolocation
# TractFIPS
# 1073000100        (23.7, 35.1)  (33.57943283260, -86.7228323926)
# 1073000300        (25.5, 40.2)  (33.54282086860, -86.7524339780)
# 1073000400        (22.0, 35.1)  (33.56324496330, -86.7640474064)
# 1073000500        (24.4, 42.9)  (33.54424045940, -86.7749130719)
# 1073000700        (33.2, 53.2)  (33.55254061390, -86.8016893706)
#
# [5 rows x 62 columns]

# %%
combined_data = health_stats.join(df)
combined_data.head()
# Out:
#            StateAbbr   PlaceName  PlaceFIPS        Place_TractID  \
# 1073000100        AL  Birmingham     107000  0107000-01073000100
# 1073000300        AL  Birmingham     107000  0107000-01073000300
# 1073000400        AL  Birmingham     107000  0107000-01073000400
# 1073000500        AL  Birmingham     107000  0107000-01073000500
# 1073000700        AL  Birmingham     107000  0107000-01073000700
#
#             Population2010  ACCESS2_CrudePrev ACCESS2_Crude95CI  \
# 1073000100            3042               23.3      (20.6, 26.3)
# 1073000300            2735               28.5      (25.2, 31.7)
# 1073000400            3338               23.9      (20.5, 27.6)
# 1073000500            2864               25.8      (22.0, 29.9)
# 1073000700            2577               29.4      (24.8, 34.2)
#
#             ARTHRITIS_CrudePrev ARTHRITIS_Crude95CI  BINGE_CrudePrev  \
# 1073000100                 31.3        (30.3, 32.5)             11.5
# 1073000300                 30.2        (29.0, 31.4)             12.0
# 1073000400                 31.7        (30.3, 33.0)             11.6
# 1073000500                 35.6        (34.1, 37.0)             10.0
# 36085027706     150.0                   0.0
# 36085027900      22.0                   0.0
# 36085029102      38.0                   0.0
# 36085029103     142.0                   0.0
# 36085029104     208.0                   0.0
# 36085030301     248.0                   0.0
# 36085030302     231.0                   0.0
# 36085031901     587.0                   1.0
# 36085031902     607.0                   1.0
# 36085032300      86.0                   0.0
#
# [2117 rows x 77 columns]

# %%
combined_data.shape
# Out:
# (27210, 77)

# %%
combined_data.rename(columns={'LILATracts_halfAnd10': 'target'}, inplace=True)
combined_data.head()
# Out:
#            StateAbbr   PlaceName  PlaceFIPS        Place_TractID  \
# 1073000100        AL  Birmingham     107000  0107000-01073000100
# 1073000300        AL  Birmingham     107000  0107000-01073000300
# 1073000400        AL  Birmingham     107000  0107000-01073000400
# 1073000500        AL  Birmingham     107000  0107000-01073000500
# 1073000700        AL  Birmingham     107000  0107000-01073000700
#
#             Population2010  ACCESS2_CrudePrev ACCESS2_Crude95CI  \
# 1073000100            3042               23.3      (20.6, 26.3)
# 1073000300            2735               28.5      (25.2, 31.7)
# 1073000400            3338               23.9      (20.5, 27.6)
# 1073000500            2864               25.8      (22.0, 29.9)
# 1073000700            2577               29.4      (24.8, 34.2)
#
#             ARTHRITIS_CrudePrev ARTHRITIS_Crude95CI  BINGE_CrudePrev   ...    \
# 1073000100                 31.3        (30.3, 32.5)             11.5   ...
# 1073000300                 30.2        (29.0, 31.4)             12.0   ...
# 1073000400                 31.7        (30.3, 33.0)             11.6   ...
# 1073000500                 35.6        (34.1, 37.0)             10.0   ...
# 1073000700                 37.2        (35.8, 38.6)              8.4   ...
#
#            TractWhite  TractBlack TractAsian  TractNHOPI TractAIAN  \
# 1073000100      530.0      2384.0       25.0         0.0       7.0
# 1073000300      498.0      1710.0       33.0         0.0       4.0
# 1073000400      256.0      2927.0       10.0         0.0       7.0
# 1073000500       83.0      2684.0        1.0        10.0       5.0
# 1073000700       12.0      2538.0        1.0         0.0       1.0
#
#             TractOMultir TractHispanic  TractHUNV TractSNAP  target
# 1073000100          96.0          82.0      141.0     260.0     1.0
# 1073000300         490.0         623.0      287.0     377.0     1.0
# 1073000400         138.0         162.0      246.0     501.0     1.0
# 1073000500          81.0          89.0      345.0     522.0     1.0
# 1073000700          25.0          12.0      198.0     506.0     1.0
#
# [5 rows x 77 columns]

# %%
to_drop = [x for x in combined_data.columns if x[-2:] == "CI"]

# %%
combined_data.drop(columns=to_drop, inplace=True)
combined_data.head()
# Out:
#            StateAbbr   PlaceName  PlaceFIPS        Place_TractID  \
# 1073000100        AL  Birmingham     107000  0107000-01073000100
# 1073000300        AL  Birmingham     107000  0107000-01073000300
# 1073000400        AL  Birmingham     107000  0107000-01073000400
# 1073000500        AL  Birmingham     107000  0107000-01073000500
# 1073000700        AL  Birmingham     107000  0107000-01073000700
#
#             Population2010  ACCESS2_CrudePrev  ARTHRITIS_CrudePrev  \
# 1073000100            3042               23.3                 31.3
# 1073000300            2735               28.5                 30.2
# 1073000400            3338               23.9                 31.7
# 1073000500            2864               25.8                 35.6
# 1073000700            2577               29.4                 37.2
#
#             BINGE_CrudePrev  BPHIGH_CrudePrev  BPMED_CrudePrev   ...    \
# 1073000100             11.5              46.2             80.0   ...
# 1073000300             12.0              45.6             80.3   ...
# 1073000400             11.6              50.1             82.0   ...
# 1073000500             10.0              54.3             84.0   ...
# 1073000700              8.4              55.4             83.3   ...
#
#             TractWhite  TractBlack  TractAsian  TractNHOPI  TractAIAN  \
# 1073000100       530.0      2384.0        25.0         0.0        7.0
# 1073000300       498.0      1710.0        33.0         0.0        4.0
# 1073000400       256.0      2927.0        10.0         0.0        7.0
# 1073000500        83.0      2684.0         1.0        10.0        5.0
# 1073000700        12.0      2538.0         1.0         0.0        1.0
#
#             TractOMultir  TractHispanic  TractHUNV  TractSNAP  target
# 1073000100          96.0           82.0      141.0      260.0     1.0
# 1073000300         490.0          623.0      287.0      377.0     1.0
# 1073000400         138.0          162.0      246.0      501.0     1.0
# 1073000500          81.0           89.0      345.0      522.0     1.0
# 1073000700          25.0           12.0      198.0      506.0     1.0
#
# [5 rows x 49 columns]

# %% [markdown]
# #### Fixing demographic columns to percentages

# %%
dem_columns = combined_data.columns[-12:-3]
for column in dem_columns:
    combined_data[column] = combined_data[column]/combined_data['Population2010']
household_columns = combined_data.columns[-3:-1]
for column in household_columns:
    combined_data[column] = combined_data[column]/combined_data['OHU2010']

# %%
combined_data.head()
# Out:
#            StateAbbr   PlaceName  PlaceFIPS        Place_TractID  \
# 1073000100        AL  Birmingham     107000  0107000-01073000100
# 1073000300        AL  Birmingham     107000  0107000-01073000300
# 1073000400        AL  Birmingham     107000  0107000-01073000400
# 1073000500        AL  Birmingham     107000  0107000-01073000500
# 1073000700        AL  Birmingham     107000  0107000-01073000700
#
#             Population2010  ACCESS2_CrudePrev  ARTHRITIS_CrudePrev  \
# 1073000100            3042               23.3                 31.3
# 1073000300            2735               28.5                 30.2
# 1073000400            3338               23.9                 31.7
# 1073000500            2864               25.8                 35.6
# 1073000700            2577               29.4                 37.2
#
#             BINGE_CrudePrev  BPHIGH_CrudePrev  BPMED_CrudePrev   ...    \
# 1073000100             11.5              46.2             80.0   ...
# 1073000300             12.0              45.6             80.3   ...
# 1073000400             11.6              50.1             82.0   ...
# 1073000500             10.0              54.3             84.0   ...
# 1073000700              8.4              55.4             83.3   ...
#
#             TractWhite  TractBlack  TractAsian  TractNHOPI  TractAIAN  \
# 1073000100    0.174227    0.783695    0.008218    0.000000   0.002301
# 1073000300    0.182084    0.625229    0.012066    0.000000   0.001463
# 1073000400    0.076693    0.876872    0.002996    0.000000   0.002097
# 1073000500    0.028980    0.937151    0.000349    0.003492   0.001746
# 1073000700    0.004657    0.984866    0.000388    0.000000   0.000388
#
#             TractOMultir  TractHispanic  TractHUNV  TractSNAP  target
# 1073000100      0.031558       0.026956   0.125000   0.230496     1.0
# 1073000300      0.179159       0.227788   0.278371   0.365664     1.0
# 1073000400      0.041342       0.048532   0.207245   0.422072     1.0
# 1073000500      0.028282       0.031075   0.289916   0.438655     1.0
# 1073000700      0.009701       0.004657   0.206681   0.528184     1.0
#
# [5 rows x 49 columns]

# %%
combined_data
# %store combined_data

# %%
plt.figure(figsize=(10,10))
sns.heatmap(combined_data.iloc[:, 4:].corr(), center=0)

# %%
correlations = combined_data.corr().abs()

# %%
upper = correlations.where(np.triu(np.ones(correlations.shape), k=1).astype(np.bool))
potential_drop = [column for column in upper.columns if any(upper[column] > .90)]

# %%
potential_drop
# Out:
# ['DENTAL_CrudePrev',
#  'KIDNEY_CrudePrev',
#  'MHLTH_CrudePrev',
#  'PHLTH_CrudePrev',
#  'STROKE_CrudePrev',
#  'TEETHLOST_CrudePrev']

# %%
abs(combined_data[potential_drop].corr())
# Out:
#                      DENTAL_CrudePrev  KIDNEY_CrudePrev  MHLTH_CrudePrev  \
# DENTAL_CrudePrev             1.000000          0.716256         0.900197
# KIDNEY_CrudePrev             0.716256          1.000000         0.615162
# MHLTH_CrudePrev              0.900197          0.615162         1.000000
# PHLTH_CrudePrev              0.877946          0.905162         0.849397
# STROKE_CrudePrev             0.684837          0.965567         0.626769
# TEETHLOST_CrudePrev          0.909600          0.781849         0.921823
#
#                      PHLTH_CrudePrev  STROKE_CrudePrev  TEETHLOST_CrudePrev
# DENTAL_CrudePrev            0.877946          0.684837             0.909600
# KIDNEY_CrudePrev            0.905162          0.965567             0.781849
# MHLTH_CrudePrev             0.849397          0.626769             0.921823
# PHLTH_CrudePrev             1.000000          0.871482             0.902989
# STROKE_CrudePrev            0.871482          1.000000             0.809911
# TEETHLOST_CrudePrev         0.902989          0.809911             1.000000

# %%
X = combined_data.drop(columns=['StateAbbr', 'PlaceName', 'PlaceFIPS', 'Place_TractID', 'target'])

# %%
test = combined_data.sample(n=500)
plt.figure(figsize=(20,20))
for i, val in enumerate(X.columns):
    plt.subplot(9, 5, i+1)
    plt.scatter(test[val], test.target)
    plt.title(val)
    plt.tight_layout()
    
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-ce8fd2338cd0> in <module>()
#       5     plt.scatter(test[val], test.target)
#       6     plt.title(val)
# ----> 7     plt.tight_layout()
#       8
#       9 plt.show()
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in tight_layout(pad, h_pad, w_pad, rect)
#    1364     """
#    1365     fig = gcf()
# -> 1366     fig.tight_layout(pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
#    1367
#    1368
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py in tight_layout(self, renderer, pad, h_pad, w_pad, rect)
#    2273         kwargs = get_tight_layout_figure(
#    2274             self, self.axes, subplotspec_list, renderer,
# -> 2275             pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
#    2276         self.subplots_adjust(**kwargs)
#    2277
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/tight_layout.py in get_tight_layout_figure(fig, axes_list, subplotspec_list, renderer, pad, h_pad, w_pad, rect)
#     326                                      subplot_list=subplot_list,
#     327                                      ax_bbox_list=ax_bbox_list,
# --> 328                                      pad=pad, h_pad=h_pad, w_pad=w_pad)
#     329
#     330     if rect is not None:
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/tight_layout.py in auto_adjust_subplotpars(fig, renderer, nrows_ncols, num1num2_list, subplot_list, ax_bbox_list, pad, h_pad, w_pad, rect)
#     112             continue
#     113
# --> 114         tight_bbox_raw = union([ax.get_tightbbox(renderer) for ax in subplots
#     115                                 if ax.get_visible()])
#     116         tight_bbox = TransformedBbox(tight_bbox_raw,
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/tight_layout.py in <listcomp>(.0)
#     113
#     114         tight_bbox_raw = union([ax.get_tightbbox(renderer) for ax in subplots
# --> 115                                 if ax.get_visible()])
#     116         tight_bbox = TransformedBbox(tight_bbox_raw,
#     117                                      fig.transFigure.inverted())
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py in get_tightbbox(self, renderer, call_axes_locator)
#    4168             bb.append(self._right_title.get_window_extent(renderer))
#    4169
# -> 4170         bb_xaxis = self.xaxis.get_tightbbox(renderer)
#    4171         if bb_xaxis:
#    4172             bb.append(bb_xaxis)
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axis.py in get_tightbbox(self, renderer)
#    1145         ticks_to_draw = self._update_ticks(renderer)
#    1146
# -> 1147         self._update_label_position(renderer)
#    1148
#    1149         # go back to just this axis's tick labels
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axis.py in _update_label_position(self, renderer)
#    1904         # get bounding boxes for this axis and any siblings
#    1905         # that have been set by `fig.align_xlabels()`
# -> 1906         bboxes, bboxes2 = self._get_tick_boxes_siblings(renderer=renderer)
#    1907
#    1908         x, y = self.label.get_position()
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axis.py in _get_tick_boxes_siblings(self, renderer)
#    1888         # if we want to align labels from other axes:
#    1889         for nn, axx in enumerate(grp.get_siblings(self.axes)):
# -> 1890             ticks_to_draw = axx.xaxis._update_ticks(renderer)
#    1891             tlb, tlb2 = axx.xaxis._get_tick_bboxes(ticks_to_draw, renderer)
#    1892             bboxes.extend(tlb)
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axis.py in _update_ticks(self, renderer)
#    1026
#    1027         interval = self.get_view_interval()
# -> 1028         tick_tups = list(self.iter_ticks())  # iter_ticks calls the locator
#    1029         if self._smart_bounds and tick_tups:
#    1030             # handle inverted limits
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axis.py in iter_ticks(self)
#     973         self.major.formatter.set_locs(majorLocs)
#     974         majorLabels = [self.major.formatter(val, i)
# --> 975                        for i, val in enumerate(majorLocs)]
#     976
#     977         minorLocs = self.minor.locator()
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axis.py in <listcomp>(.0)
#     973         self.major.formatter.set_locs(majorLocs)
#     974         majorLabels = [self.major.formatter(val, i)
# --> 975                        for i, val in enumerate(majorLocs)]
#     976
#     977         minorLocs = self.minor.locator()
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/category.py in __call__(self, x, pos)
#     152             return ""
#     153         r_mapping = {v: StrCategoryFormatter._text(k)
# --> 154                      for k, v in self._units.items()}
#     155         return r_mapping.get(int(np.round(x)), '')
#     156
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/category.py in <dictcomp>(.0)
#     152             return ""
#     153         r_mapping = {v: StrCategoryFormatter._text(k)
# --> 154                      for k, v in self._units.items()}
#     155         return r_mapping.get(int(np.round(x)), '')
#     156
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/category.py in _text(value)
#     159         """Converts text values into `utf-8` or `ascii` strings
#     160         """
# --> 161         if LooseVersion(np.__version__) < LooseVersion('1.7.0'):
#     162             if (isinstance(value, (six.text_type, np.unicode))):
#     163                 value = value.encode('utf-8', 'ignore').decode('utf-8')
#
# ~/anaconda3/lib/python3.6/distutils/version.py in __init__(self, vstring)
#     302     def __init__ (self, vstring=None):
#     303         if vstring:
# --> 304             self.parse(vstring)
#     305
#     306
#
# ~/anaconda3/lib/python3.6/distutils/version.py in parse(self, vstring)
#     310         # use by __str__
#     311         self.vstring = vstring
# --> 312         components = [x for x in self.component_re.split(vstring)
#     313                               if x and x != '.']
#     314         for i, obj in enumerate(components):
#
# KeyboardInterrupt:
